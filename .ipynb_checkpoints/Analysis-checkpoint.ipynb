# %% [markdown]
# # Predicting Housing Sale Prices in Ames, Iowa
#
# ----
#
#
#
#
# ### Project Description
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, our goal is to predict the final price of each home of the test data set using the training data set.
#
#
# ### Datasets
#
# 80 Columns x 1460 Rows of housing sales data from years 2006 to 2010
#
# Source: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %%
# Dependencies and Setup
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# Importing Data
data = pd.read_csv("data.csv")
#data.info()

# %%
# Select non object columns (and Set NA to 0)
df = data.select_dtypes(exclude=['object'])
df = df.rename(columns={"1stFlrSF" : "X1stFlrSF", "2ndFlrSF" : "X2ndFlrSF"})
df.fillna(0, inplace=True)
df.isnull().any().any()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1460 non-null float64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# X1stFlrSF        1460 non-null int64
# X2ndFlrSF        1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# Fireplaces       1460 non-null int64
# GarageYrBlt      1460 non-null float64
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35)
# memory usage: 433.5 KB

# %% [markdown]
# ## One-way plots

# %%
# Graphs target variable (SalePrice) vs each independent variable
# First 9 variables excluding Id
j = 1 #select the starting field for the 9 plots
fig = plt.figure(figsize=(12,8))
target = "SalePrice"

# loop plotting
for i in range(9):
    field1 = df.columns[j]
    oneway = df[[field1,target]]
    plt.subplot(3,3,i+1)
    try:
        plt.scatter(oneway[field1],oneway[target])
    except:
        plt.scatter(0,0)
    plt.title("Chart " + str(j))
    plt.xlabel(oneway.columns[0])
    plt.ylabel(oneway.columns[1])
    j=j+1

plt.tight_layout()
#Code to save to file
#plt.savefig("Images/Group9.png")
plt.show()

# %%
# Graphs target variable (SalePrice) vs each independent variable
# 10-18 variables excluding Id
j = 10 #select the starting field for the 9 plots
fig = plt.figure(figsize=(12,8))
target = "SalePrice"

# loop plotting
for i in range(9):
    field1 = df.columns[j]
    oneway = df[[field1,target]]
    plt.subplot(3,3,i+1)
    try:
        plt.scatter(oneway[field1],oneway[target])
    except:
        plt.scatter(0,0)
    plt.title("Chart " + str(j))
    plt.xlabel(oneway.columns[0])
    plt.ylabel(oneway.columns[1])
    j=j+1

plt.tight_layout()
#Code to save to file
#plt.savefig("Images/Group9.png")
plt.show()

# %%
# Graphs target variable (SalePrice) vs each independent variable
# 19-27 variables excluding Id
j = 19 #select the starting field for the 9 plots
fig = plt.figure(figsize=(12,8))
target = "SalePrice"

# loop plotting
for i in range(9):
    field1 = df.columns[j]
    oneway = df[[field1,target]]
    plt.subplot(3,3,i+1)
    try:
        plt.scatter(oneway[field1],oneway[target])
    except:
        plt.scatter(0,0)
    plt.title("Chart " + str(j))
    plt.xlabel(oneway.columns[0])
    plt.ylabel(oneway.columns[1])
    j=j+1

plt.tight_layout()
#Code to save to file
#plt.savefig("Images/Group9.png")
plt.show()

# %%
# Graphs target variable (SalePrice) vs each independent variable
# 29-38 variables excluding Id
j = 28 #select the starting field for the 9 plots
fig = plt.figure(figsize=(12,8))
target = "SalePrice"

# loop plotting
for i in range(9):
    field1 = df.columns[j]
    oneway = df[[field1,target]]
    plt.subplot(3,3,i+1)
    try:
        plt.scatter(oneway[field1],oneway[target])
    except:
        plt.scatter(0,0)
    plt.title("Chart " + str(j))
    plt.xlabel(oneway.columns[0])
    plt.ylabel(oneway.columns[1])
    j=j+1

plt.tight_layout()
#Code to save to file
#plt.savefig("Images/Group9.png")
plt.show()

# %% [markdown]
# ### Initial Modeling and Variable Selection

# %%
# Single variable model
import statsmodels.api as sm

i=1 # select indepenedent varaible
model = sm.GLM(df["SalePrice"], df[df.columns[i]]).fit()
print(model.deviance)
print(df.columns[i])
print(model.summary())
# Out:
# 27881724499315.305
# MSSubClass
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1460
# Model:                            GLM   Df Residuals:                     1459
# Model Family:                Gaussian   Df Model:                            0
# Link Function:               identity   Scale:                      1.9110e+10
# Method:                          IRLS   Log-Likelihood:                -19353.
# Date:                Wed, 12 Feb 2020   Deviance:                   2.7882e+13
# Time:                        15:04:13   Pearson chi2:                 2.79e+13
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# MSSubClass  1992.0521     51.035     39.033      0.000    1892.025    2092.079
# ==============================================================================

# %%
# Ordinary least squares - Single variable - Get Model Deviance
dev_comp = pd.DataFrame()
fields = []
dev = []

# Calculating Deviance
for i in range(37): 
    fields.append(df.columns[i])
    model = sm.GLM(df["SalePrice"], df[df.columns[i]]).fit()
    dev.append(model.deviance)
        
# Output deviance measures and rank by decending
dev_comp["Fields"] = fields
dev_comp["Deviation"] = dev
dev_comp = dev_comp.sort_values(by="Deviation", ascending=True)
print(dev_comp.head(15))
# Out:
#           Fields     Deviation
# 4    OverallQual  4.107325e+12
# 16     GrLivArea  4.638169e+12
# 13     X1stFlrSF  6.018164e+12
# 26    GarageCars  6.244985e+12
# 23  TotRmsAbvGrd  6.595085e+12
# 12   TotalBsmtSF  6.603424e+12
# 19      FullBath  6.789312e+12
# 27    GarageArea  6.889724e+12
# 6      YearBuilt  8.882602e+12
# 7   YearRemodAdd  8.991631e+12
# 36        YrSold  9.208735e+12
# 25   GarageYrBlt  9.318008e+12
# 21  BedroomAbvGr  1.090938e+13
# 5    OverallCond  1.166221e+13
# 22  KitchenAbvGr  1.237681e+13

# %%
#df = df.drop("SalePrice", 1)
model1 = sm.GLM(df["SalePrice"], df.drop("SalePrice", 1)).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1460
# Model:                            GLM   Df Residuals:                     1425
# Model Family:                Gaussian   Df Model:                           34
# Link Function:               identity   Scale:                      1.1863e+09
# Method:                          IRLS   Log-Likelihood:                -17307.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.6905e+12
# Time:                        15:04:13   Pearson chi2:                 1.69e+12
# No. Iterations:                     3   Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Id               -1.0568      2.167     -0.488      0.626      -5.304       3.191
# MSSubClass     -166.8371     26.451     -6.307      0.000    -218.680    -114.995
# LotFrontage       8.8298     28.512      0.310      0.757     -47.052      64.712
# LotArea           0.3925      0.100      3.931      0.000       0.197       0.588
# OverallQual    1.729e+04   1179.488     14.662      0.000     1.5e+04    1.96e+04
# OverallCond    5109.4769   1022.193      4.999      0.000    3106.016    7112.937
# YearBuilt       339.6431     60.251      5.637      0.000     221.552     457.734
# YearRemodAdd    122.0988     66.001      1.850      0.064      -7.260     251.458
# MasVnrArea       28.0527      5.916      4.742      0.000      16.457      39.648
# BsmtFinSF1        9.5685      2.507      3.816      0.000       4.654      14.483
# BsmtFinSF2        0.0461      4.471      0.010      0.992      -8.717       8.810
# BsmtUnfSF        -0.5535      2.393     -0.231      0.817      -5.243       4.136
# TotalBsmtSF       9.0612      3.340      2.713      0.007       2.514      15.608
# X1stFlrSF        18.6226      6.087      3.060      0.002       6.693      30.552
# X2ndFlrSF        19.8636      5.639      3.523      0.000       8.812      30.916
# LowQualFinSF    -10.2370     14.713     -0.696      0.487     -39.075      18.601
# GrLivArea        28.2492      5.626      5.021      0.000      17.222      39.276
# BsmtFullBath   8488.2641   2587.626      3.280      0.001    3416.610    1.36e+04
# BsmtHalfBath   1744.1045   4051.195      0.431      0.667   -6196.092    9684.301
# FullBath       3175.5834   2794.370      1.136      0.256   -2301.280    8652.447
# HalfBath      -1945.9578   2639.345     -0.737      0.461   -7118.979    3227.063
# BedroomAbvGr  -1.026e+04   1679.257     -6.111      0.000   -1.36e+04   -6970.679
# KitchenAbvGr  -1.583e+04   5189.430     -3.051      0.002    -2.6e+04   -5660.802
# TotRmsAbvGrd   5014.9160   1227.193      4.086      0.000    2609.661    7420.171
# Fireplaces     4082.7314   1756.769      2.324      0.020     639.527    7525.935
# GarageYrBlt     -14.5761      2.682     -5.434      0.000     -19.833      -9.319
# GarageCars     1.572e+04   2971.965      5.288      0.000    9890.708    2.15e+04
# GarageArea        4.9542      9.712      0.510      0.610     -14.081      23.990
# WoodDeckSF       25.6914      7.918      3.245      0.001      10.172      41.210
# OpenPorchSF      -6.0518     15.037     -0.402      0.687     -35.523      23.420
# EnclosedPorch    11.8483     16.695      0.710      0.478     -20.873      44.570
# 3SsnPorch        19.9726     31.117      0.642      0.521     -41.015      80.960
# ScreenPorch      57.6141     17.031      3.383      0.001      24.234      90.994
# PoolArea        -31.6704     23.493     -1.348      0.178     -77.717      14.376
# MiscVal          -0.4822      1.843     -0.262      0.794      -4.095       3.130
# MoSold          -24.2537    338.057     -0.072      0.943    -686.834     638.327
# YrSold         -473.1944     66.795     -7.084      0.000    -604.111    -342.278
# =================================================================================
# """

# %%
# Select fields with P value less than 0.05
import statsmodels.formula.api as smf
results = pd.read_html(model1.summary().tables[1].as_html(), header=0, index_col=0)[0]
fields = list(results[results['P>|z|']<=0.05].index)
formula = "SalePrice" + " ~ " + " + ".join(fields)
model2 = smf.glm(formula = formula, data = df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1460
# Model:                            GLM   Df Residuals:                     1438
# Model Family:                Gaussian   Df Model:                           21
# Link Function:               identity   Scale:                      1.1848e+09
# Method:                          IRLS   Log-Likelihood:                -17312.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.7037e+12
# Time:                        15:04:14   Pearson chi2:                 1.70e+12
# No. Iterations:                     3   Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2.951e+05   1.37e+06      0.215      0.830    -2.4e+06    2.99e+06
# MSSubClass    -166.1066     25.687     -6.467      0.000    -216.452    -115.761
# LotArea          0.3970      0.099      4.008      0.000       0.203       0.591
# OverallQual   1.796e+04   1142.795     15.718      0.000    1.57e+04    2.02e+04
# OverallCond   5836.4164    919.134      6.350      0.000    4034.947    7637.885
# YearBuilt      384.7167     45.227      8.506      0.000     296.074     473.360
# MasVnrArea      26.9475      5.797      4.648      0.000      15.585      38.310
# BsmtFinSF1       9.2086      3.008      3.062      0.002       3.313      15.104
# TotalBsmtSF      8.1804      4.096      1.997      0.046       0.153      16.208
# X1stFlrSF       30.2790     20.007      1.513      0.130      -8.933      69.491
# X2ndFlrSF       29.1028     19.571      1.487      0.137      -9.256      67.462
# GrLivArea       19.2110     19.517      0.984      0.325     -19.042      57.464
# BsmtFullBath  8323.9249   2352.372      3.539      0.000    3713.360    1.29e+04
# BedroomAbvGr -1.045e+04   1626.908     -6.422      0.000   -1.36e+04   -7259.618
# KitchenAbvGr -1.524e+04   5088.040     -2.995      0.003   -2.52e+04   -5267.028
# TotRmsAbvGrd  5149.2473   1212.534      4.247      0.000    2772.724    7525.771
# Fireplaces    3358.7499   1716.336      1.957      0.050      -5.207    6722.707
# GarageYrBlt    -15.5137      2.602     -5.963      0.000     -20.613     -10.414
# GarageCars    1.764e+04   2033.257      8.676      0.000    1.37e+04    2.16e+04
# WoodDeckSF      25.3002      7.800      3.244      0.001      10.012      40.588
# ScreenPorch     51.7933     16.711      3.099      0.002      19.041      84.546
# YrSold        -546.8257    684.156     -0.799      0.424   -1887.747     794.096
# ================================================================================
# """

# %%
# Select fields with P value less than 0.05
results = pd.read_html(model2.summary().tables[1].as_html(), header=0, index_col=0)[0]
fields = list(results[results['P>|z|']<=0.05].index)
formula = "SalePrice" + " ~ " + " + ".join(fields)
model3 = smf.glm(formula = formula, data = df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1460
# Model:                            GLM   Df Residuals:                     1442
# Model Family:                Gaussian   Df Model:                           17
# Link Function:               identity   Scale:                      1.3085e+09
# Method:                          IRLS   Log-Likelihood:                -17387.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.8869e+12
# Time:                        15:04:14   Pearson chi2:                 1.89e+12
# No. Iterations:                     3   Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -6.522e+05   9.16e+04     -7.121      0.000   -8.32e+05   -4.73e+05
# MSSubClass    -104.8773     25.425     -4.125      0.000    -154.708     -55.046
# LotArea          0.5338      0.103      5.163      0.000       0.331       0.736
# OverallQual   2.166e+04   1156.070     18.736      0.000    1.94e+04    2.39e+04
# OverallCond   5232.7120    962.605      5.436      0.000    3346.042    7119.382
# YearBuilt      295.7005     46.281      6.389      0.000     204.991     386.410
# MasVnrArea      33.8920      6.050      5.602      0.000      22.034      45.750
# BsmtFinSF1      13.7674      3.135      4.391      0.000       7.623      19.912
# TotalBsmtSF     15.2481      3.223      4.732      0.000       8.932      21.564
# BsmtFullBath  5473.5995   2454.317      2.230      0.026     663.228    1.03e+04
# BedroomAbvGr -7979.9938   1680.806     -4.748      0.000   -1.13e+04   -4685.675
# KitchenAbvGr -1.994e+04   5135.699     -3.882      0.000      -3e+04   -9870.067
# TotRmsAbvGrd  1.402e+04   1020.963     13.729      0.000     1.2e+04     1.6e+04
# Fireplaces    7250.8080   1755.713      4.130      0.000    3809.673    1.07e+04
# GarageYrBlt    -16.6573      2.716     -6.132      0.000     -21.981     -11.333
# GarageCars    2.053e+04   2117.166      9.698      0.000    1.64e+04    2.47e+04
# WoodDeckSF      33.3628      8.161      4.088      0.000      17.368      49.358
# ScreenPorch     56.3016     17.550      3.208      0.001      21.905      90.699
# ================================================================================
# """

# %% [markdown]
# ### Selected Fields

# %%
# Selected independent fields (scaled)
X = df[fields].copy()
X = (X - X.min()) / (X.max() - X.min())
X = sm.add_constant(X)
X.describe()
# Out:
# C:\Users\mryet\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#         const   MSSubClass      LotArea  OverallQual  OverallCond  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000
# mean      1.0     0.217043     0.043080     0.566591     0.571918
# std       0.0     0.248827     0.046653     0.153666     0.139100
# min       1.0     0.000000     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     0.029229     0.444444     0.500000
# 50%       1.0     0.176471     0.038227     0.555556     0.500000
# 75%       1.0     0.294118     0.048150     0.666667     0.625000
# max       1.0     1.000000     1.000000     1.000000     1.000000
#
#          YearBuilt   MasVnrArea   BsmtFinSF1  TotalBsmtSF  BsmtFullBath  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean      0.719332     0.064448     0.078604     0.173065      0.141781
# std       0.218862     0.112957     0.080811     0.071801      0.172970
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.594203     0.000000     0.000000     0.130237      0.000000
# 50%       0.731884     0.000000     0.067948     0.162275      0.000000
# 75%       0.927536     0.102656     0.126196     0.212480      0.333333
# max       1.000000     1.000000     1.000000     1.000000      1.000000
#
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean       0.358305      0.348858      0.376484     0.204338     0.929721
# std        0.101972      0.073446      0.135449     0.214889     0.225720
# min        0.000000      0.000000      0.000000     0.000000     0.000000
# 25%        0.250000      0.333333      0.250000     0.000000     0.974129
# 50%        0.375000      0.333333      0.333333     0.333333     0.983582
# 75%        0.375000      0.333333      0.416667     0.333333     0.995522
# max        1.000000      1.000000      1.000000     1.000000     1.000000
#
#         GarageCars   WoodDeckSF  ScreenPorch
# count  1460.000000  1460.000000  1460.000000
# mean      0.441781     0.109970     0.031377
# std       0.186829     0.146253     0.116161
# min       0.000000     0.000000     0.000000
# 25%       0.250000     0.000000     0.000000
# 50%       0.500000     0.000000     0.000000
# 75%       0.500000     0.196033     0.000000
# max       1.000000     1.000000     1.000000

# %% [markdown]
# ### Histograms - Sales Price

# %%
# Plot Histogram of Sales Price
y = df["SalePrice"]
plt.hist(y, density=True, bins=30)
plt.xticks(rotation = 45)
plt.title("Histogram of Sale Price")
plt.xlabel("Sale Price")
plt.ylabel("Frequency")
#plt.savefig("histsp.png")
plt.show()

# %% [markdown]
# ### Model Setup

# %%
# split into traingin and testing models
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# ### Models

# %%
# Identiy link function
ind = sm.GLM(y_train, X_train, family=sm.families.Gaussian()).fit()
print(ind.summary())

print("")
print("")

# Identiy log function
log = sm.GLM(y_train, X_train, family=sm.families.Gaussian(sm.families.links.log)).fit()
print(log.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1022
# Model:                            GLM   Df Residuals:                     1004
# Model Family:                Gaussian   Df Model:                           17
# Link Function:               identity   Scale:                      1.3429e+09
# Method:                          IRLS   Log-Likelihood:                -12181.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.3483e+12
# Time:                        15:04:14   Pearson chi2:                 1.35e+12
# No. Iterations:                     3   Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -4.585e+04   1.36e+04     -3.359      0.001   -7.26e+04   -1.91e+04
# MSSubClass   -1.897e+04   5367.234     -3.534      0.000   -2.95e+04   -8445.750
# LotArea       1.178e+05   2.57e+04      4.591      0.000    6.75e+04    1.68e+05
# OverallQual   1.848e+05   1.27e+04     14.517      0.000     1.6e+05     2.1e+05
# OverallCond   4.508e+04   9348.438      4.823      0.000    2.68e+04    6.34e+04
# YearBuilt     4.589e+04   7752.526      5.919      0.000    3.07e+04    6.11e+04
# MasVnrArea    5.011e+04   1.25e+04      4.015      0.000    2.56e+04    7.46e+04
# BsmtFinSF1    4.809e+04   2.12e+04      2.273      0.023    6614.762    8.96e+04
# TotalBsmtSF   7.658e+04   2.35e+04      3.263      0.001    3.06e+04    1.23e+05
# BsmtFullBath   1.87e+04   8809.301      2.123      0.034    1433.711     3.6e+04
# BedroomAbvGr -5.985e+04   1.71e+04     -3.507      0.000   -9.33e+04   -2.64e+04
# KitchenAbvGr -5.748e+04   2.03e+04     -2.825      0.005   -9.73e+04   -1.76e+04
# TotRmsAbvGrd  1.626e+05   1.53e+04     10.624      0.000    1.33e+05    1.93e+05
# Fireplaces    2.267e+04   6289.442      3.604      0.000    1.03e+04     3.5e+04
# GarageYrBlt  -3.065e+04   7014.981     -4.370      0.000   -4.44e+04   -1.69e+04
# GarageCars    8.502e+04   1.04e+04      8.211      0.000    6.47e+04    1.05e+05
# WoodDeckSF    3.659e+04   8409.747      4.351      0.000    2.01e+04    5.31e+04
# ScreenPorch    3.67e+04   9917.064      3.701      0.000    1.73e+04    5.61e+04
# ================================================================================
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1022
# Model:                            GLM   Df Residuals:                     1004
# Model Family:                Gaussian   Df Model:                           17
# Link Function:                    log   Scale:                      1.1883e+09
# Method:                          IRLS   Log-Likelihood:                -12119.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.1930e+12
# Time:                        15:04:14   Pearson chi2:                 1.19e+12
# No. Iterations:                    15   Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.6520      0.093    113.938      0.000      10.469      10.835
# MSSubClass      -0.1377      0.030     -4.603      0.000      -0.196      -0.079
# LotArea          0.4042      0.085      4.777      0.000       0.238       0.570
# OverallQual      1.0439      0.063     16.563      0.000       0.920       1.167
# OverallCond      0.3635      0.055      6.641      0.000       0.256       0.471
# YearBuilt        0.3636      0.044      8.300      0.000       0.278       0.449
# MasVnrArea       0.1768      0.047      3.799      0.000       0.086       0.268
# BsmtFinSF1      -0.1986      0.091     -2.177      0.029      -0.377      -0.020
# TotalBsmtSF     -0.0627      0.099     -0.636      0.525      -0.256       0.131
# BsmtFullBath     0.2125      0.046      4.666      0.000       0.123       0.302
# BedroomAbvGr    -0.0861      0.083     -1.038      0.299      -0.249       0.077
# KitchenAbvGr    -0.2577      0.135     -1.912      0.056      -0.522       0.007
# TotRmsAbvGrd     0.5889      0.068      8.709      0.000       0.456       0.721
# Fireplaces       0.2072      0.031      6.643      0.000       0.146       0.268
# GarageYrBlt     -0.0889      0.055     -1.629      0.103      -0.196       0.018
# GarageCars       0.5235      0.053      9.862      0.000       0.419       0.627
# WoodDeckSF       0.1903      0.037      5.126      0.000       0.118       0.263
# ScreenPorch      0.2188      0.039      5.549      0.000       0.142       0.296
# ================================================================================

# %%
# Plots for Train Dataset
min = 0
max = 800000
pred_ind = ind.predict(X_train)
pred_log = log.predict(X_train)

fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Actual vs Predicted - Train Datset")
plt.scatter(pred_ind, y_train, s = 5, color="blue", label="Ind")
plt.scatter(pred_log, y_train, s = 5, color="red", label="Log")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.plot([0,max],[0,max])
plt.xticks(rotation = 60)
plt.xlim(min,max)
plt.ylim(min,max)

plt.subplot(1,2,2)
plt.title("Q-Q Plot - Train Datset")
plt.scatter(np.sort(pred_ind), np.sort(y_train), s = 5, color="blue", label="Ind")
plt.scatter(np.sort(pred_log), np.sort(y_train), s = 5, color="red", label="Log")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.plot([0,max],[0,max])
plt.xticks(rotation = 60)
plt.xlim(min,max)
plt.ylim(min,max)

plt.show()

# %%
# Plots for Test Dataset
min = 0
max = 800000
pred_ind_test = ind.predict(X_test)
pred_log_test = log.predict(X_test)

fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Actual vs Predicted - Test Datset")
plt.scatter(pred_ind_test, y_test, s = 5, color="blue", label="Ind")
plt.scatter(pred_log_test, y_test, s = 5, color="red", label="Log")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.plot([0,max],[0,max])
plt.xticks(rotation = 60)
plt.xlim(min,max)
plt.ylim(min,max)

plt.subplot(1,2,2)
plt.title("Q-Q Plot - Test Datset")
plt.scatter(np.sort(pred_ind_test), np.sort(y_test), s = 5, color="blue", label="Ind")
plt.scatter(np.sort(pred_log_test), np.sort(y_test), s = 5, color="red", label="Log")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.plot([0,max],[0,max])
plt.xticks(rotation = 60)
plt.xlim(min,max)
plt.ylim(min,max)

plt.show()

# %%
# Calculate the mean squared error
from sklearn.metrics import mean_squared_error
mse = np.sqrt(mean_squared_error(y_train,pred_log))
avg = np.mean(y_train)
print("Train Data - MSE: " + '{0:,.0f}'.format(mse) + " and Mean Value: " + '{0:,.0f}'.format(avg))

mse = np.sqrt(mean_squared_error(y_test,pred_log_test))
avg = np.mean(y_test)
print("Test Data - MSE: " + '{0:,.0f}'.format(mse) + " and Mean Value: " + '{0:,.0f}'.format(avg))
# Out:
# Train Data - MSE: 34,166 and Mean Value: 181,439
# Test Data - MSE: 33,134 and Mean Value: 179,714

# %%
X1 = X.drop(["TotalBsmtSF","BedroomAbvGr","KitchenAbvGr","GarageYrBlt"],axis=1)
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y, test_size=0.30, random_state=1)
X1.describe()
# Out:
#         const   MSSubClass      LotArea  OverallQual  OverallCond  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000
# mean      1.0     0.217043     0.043080     0.566591     0.571918
# std       0.0     0.248827     0.046653     0.153666     0.139100
# min       1.0     0.000000     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     0.029229     0.444444     0.500000
# 50%       1.0     0.176471     0.038227     0.555556     0.500000
# 75%       1.0     0.294118     0.048150     0.666667     0.625000
# max       1.0     1.000000     1.000000     1.000000     1.000000
#
#          YearBuilt   MasVnrArea   BsmtFinSF1  BsmtFullBath  TotRmsAbvGrd  \
# count  1460.000000  1460.000000  1460.000000   1460.000000   1460.000000
# mean      0.719332     0.064448     0.078604      0.141781      0.376484
# std       0.218862     0.112957     0.080811      0.172970      0.135449
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.594203     0.000000     0.000000      0.000000      0.250000
# 50%       0.731884     0.000000     0.067948      0.000000      0.333333
# 75%       0.927536     0.102656     0.126196      0.333333      0.416667
# max       1.000000     1.000000     1.000000      1.000000      1.000000
#
#         Fireplaces   GarageCars   WoodDeckSF  ScreenPorch
# count  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.204338     0.441781     0.109970     0.031377
# std       0.214889     0.186829     0.146253     0.116161
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.250000     0.000000     0.000000
# 50%       0.333333     0.500000     0.000000     0.000000
# 75%       0.333333     0.500000     0.196033     0.000000
# max       1.000000     1.000000     1.000000     1.000000

# %%
log1 = sm.GLM(y1_train, X1_train, family=sm.families.Gaussian(sm.families.links.log)).fit()
print(log1.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1022
# Model:                            GLM   Df Residuals:                     1008
# Model Family:                Gaussian   Df Model:                           13
# Link Function:                    log   Scale:                      1.1925e+09
# Method:                          IRLS   Log-Likelihood:                -12123.
# Date:                Wed, 12 Feb 2020   Deviance:                   1.2020e+12
# Time:                        15:04:15   Pearson chi2:                 1.20e+12
# No. Iterations:                    12   Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.4495      0.056    187.794      0.000      10.340      10.559
# MSSubClass      -0.1428      0.028     -5.167      0.000      -0.197      -0.089
# LotArea          0.3923      0.083      4.705      0.000       0.229       0.556
# OverallQual      1.0843      0.056     19.390      0.000       0.975       1.194
# OverallCond      0.3737      0.054      6.947      0.000       0.268       0.479
# YearBuilt        0.3685      0.043      8.476      0.000       0.283       0.454
# MasVnrArea       0.1789      0.046      3.866      0.000       0.088       0.270
# BsmtFinSF1      -0.2354      0.074     -3.167      0.002      -0.381      -0.090
# BsmtFullBath     0.2227      0.044      5.014      0.000       0.136       0.310
# TotRmsAbvGrd     0.5235      0.049     10.595      0.000       0.427       0.620
# Fireplaces       0.2142      0.031      6.981      0.000       0.154       0.274
# GarageCars       0.4783      0.049      9.768      0.000       0.382       0.574
# WoodDeckSF       0.1925      0.037      5.209      0.000       0.120       0.265
# ScreenPorch      0.2216      0.039      5.628      0.000       0.144       0.299
# ================================================================================

# %%
pred_log1 = log1.predict(X1_train)
pred_log1_test = log1.predict(X1_test)
mse = np.sqrt(mean_squared_error(y1_train,pred_log1))
avg = np.mean(y1_train)
print("Train Data - MSE: " + '{0:,.0f}'.format(mse) + " and Mean Value: " + '{0:,.0f}'.format(avg))

mse = np.sqrt(mean_squared_error(y1_test,pred_log1_test))
avg = np.mean(y1_test)
print("Test Data - MSE: " + '{0:,.0f}'.format(mse) + " and Mean Value: " + '{0:,.0f}'.format(avg))
# Out:
# Train Data - MSE: 34,295 and Mean Value: 181,439
# Test Data - MSE: 33,279 and Mean Value: 179,714

# %%
del X1["const"]
corr = X1.corr()
corr.style.background_gradient(cmap='coolwarm',axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col1 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col2 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col5 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col6 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col7 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col8 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col9 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col10 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col11 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow0_col12 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col0 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col2 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col6 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col7 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col8 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col9 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col10 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col11 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow1_col12 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col0 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col1 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col4 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col5 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col7 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col8 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col9 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col10 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col11 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow2_col12 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col1 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col5 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col6 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col8 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col9 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col10 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col11 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow3_col12 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col0 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col2 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col6 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_f23bdefe_4ddb_11ea_8495_b831b5806a6drow4_col7 {
#             background-color:  #c3d5f4;
#             color:
